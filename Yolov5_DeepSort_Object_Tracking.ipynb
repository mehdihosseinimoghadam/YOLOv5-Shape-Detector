# %% [markdown]
# <a href="https://colab.research.google.com/github/mehdihosseinimoghadam/YOLOv5-Shape-Detector/blob/main/Yolov5_DeepSort_Object_Tracking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone --recurse-submodules https://github.com/mikel-brostrom/Yolov5_StrongSORT_OSNet.git  # clone repo
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.12.0+cu113 (Tesla T4)

# %%
# !gdown https://drive.google.com/uc?id=1nXiNOfZRfovIWDz00rgSbFJp2a0mlHrX
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1nXiNOfZRfovIWDz00rgSbFJp2a0mlHrX
# To: /content/best.pt
# 100% 14.3M/14.3M [00:00<00:00, 25.8MB/s]

# %%
cd /content/Yolov5_StrongSORT_OSNet
# Out:
# /content/Yolov5_StrongSORT_OSNet

# %% [markdown]
# ## First run this cell, then restart the run time and run it again ;)

# %%
# !python track.py --yolo-weights /content/best.pt --strong-sort-weights /content/Yolov5_StrongSORT_OSNet/strong_sort/deep/checkpoint/osnet_x1_0_msmt17.pth --source /content/test2.mp4 --save-vid  # output will be in Yolov5_StrongSORT_OSNet/runs/track
# Out:
# strong_sort/deep/reid/torchreid/metrics/rank.py:12: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython evaluation (very fast so highly recommended) is '
# track: yolo_weights=['/content/best.pt'], strong_sort_weights=/content/Yolov5_StrongSORT_OSNet/strong_sort/deep/checkpoint/osnet_x1_0_msmt17.pth, config_strongsort=strong_sort/configs/strong_sort.yaml, source=/content/Yolov5_StrongSORT_OSNet/test2.mp4, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.5, max_det=1000, device=, show_vid=False, save_txt=False, save_conf=False, save_crop=False, save_vid=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/track, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, hide_class=False, half=False, dnn=False
# requirements: tb-nightly not found and is required by YOLOv5, attempting auto-update...
# ...
